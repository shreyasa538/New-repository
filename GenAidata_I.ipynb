# %% [markdown]
# <a href="https://colab.research.google.com/github/shreyasa538/New-repository/blob/main/GenAidata_I.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("/content/static.csv")
data.drop(data.tail(1).index,inplace=True)
data['period_end']=pd.to_datetime(data['period_end'])

# %%
plt.figure(figsize=(15,6))
sns.set_theme(style="whitegrid")
plt.title("number of followers gained every month")
sns.barplot(x="period_end",y="followers_gained",data=data)
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
#Plot 2: Total followers

plt.figure(figsize=(15, 6))

sns.set_theme(style="whitegrid")

plt.title("Total Followers At The End of Every Month")

sns.barplot(x="period_end", y="followers_total", data=data)

plt.xticks(rotation=45)

plt.tight_layout()

plt.show()

# %%
plt.figure(figsize=(15, 6))

sns.set_theme(style="whitegrid")

plt.title("Total Views Every Month")

sns.barplot(x="period_end", y="views", data=data)

plt.xticks(rotation=45)

plt.tight_layout()

plt.show()

# %%
pip install autots
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 974.9/974.9 kB 24.8 MB/s eta 0:00:00
# ...

# %%
from autots import AutoTS

#Make sure only the necessary data is passed

ts_data = data[['period_end', 'followers_gained']].copy()

model = AutoTS(
forecast_length=2,
frequency='infer',
ensemble='simple',
min_allowed_train_percent=0.3

)

model = model.fit(ts_data, date_col='period_end', value_col='followers_gained', id_col=None)
prediction = model.predict()
forecast = prediction.forecast
print(forecast)
# Out:
# Using 1 cpus for n_jobs.
# Data frequency is: ME, used frequency is: ME
# Model Number: 1 with model AverageValueNaive in generation 0 of 25
# Model Number: 2 with model AverageValueNaive in generation 0 of 25
# Model Number: 3 with model AverageValueNaive in generation 0 of 25
# Model Number: 4 with model DatepartRegression in generation 0 of 25
# Model Number: 5 with model DatepartRegression in generation 0 of 25
# Model Number: 6 with model DatepartRegression in generation 0 of 25
# /usr/local/lib/python3.11/dist-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Model Number: 7 with model DatepartRegression in generation 0 of 25
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# ...
